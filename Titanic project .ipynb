# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
T1=titanic=pd.read_csv(r"C:\Users\user\Desktop\TITANIC.csv")

# %% [markdown]
# ## 1.Who were the passengers on the Titanic? (Ages,Gender,Class,..etc)

# %%
titanic.head()
# Out:
#       Sex  PassengerId  Survived  Pclass  \
# 0    male            1         0       3
# 1  female            2         1       1
# 2  female            3         1       3
# 3  female            4         1       1
# 4    male            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Person
# 0         A/5 21171   7.2500   NaN        S    male
# 1          PC 17599  71.2833   C85        C  female
# 2  STON/O2. 3101282   7.9250   NaN        S  female
# 3            113803  53.1000  C123        S  female
# ...

# %%
# Find the oldest male
oldest_male = titanic[titanic['Sex'] == 'male'].sort_values('Age', ascending=False).iloc[0]

# %%
oldest_male
# Out:
# Sex                                            male
# PassengerId                                     631
# Survived                                          1
# Pclass                                            1
# Name           Barkworth, Mr. Algernon Henry Wilson
# Age                                            80.0
# SibSp                                             0
# Parch                                             0
# Ticket                                        27042
# Fare                                           30.0
# Cabin                                           A23
# Embarked                                          S
# Person                                         male
# Name: 630, dtype: object

# %%
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
titanic.duplicated().sum()
# Out:
# 0

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## BASIC QUESTIONS YOU'VE TO ANSWER

# %% [markdown]
# All good data analysis projects begin with trying to answer questions. Now that we know what column category data we have let's think of some questions or insights we would like to obtain from the data. So here's a list of questions we'll try to answer using our new data analysis skills!
#
# First some basic questions:
#
# 1.) Who were the passengers on the Titanic? (Ages,Gender,Class,..etc)
# 2.) What deck were the passengers on and how does that relate to their class?
# 3.) Where did the passengers come from?
# 4.) Who was alone and who was with family?

# %%
sns.countplot(x='Sex',data=titanic)
plt.show()

# %%
sns.countplot(x='Pclass',data=titanic,hue='Sex')
plt.show()

# %%
titanic['Sex'].max()
# Out:
# 'male'

# %%
# We'll treat anyone as under 16 as a child, and then use the apply technique with a function to create a new column

# Revisit Lecture 45 for a refresher on how to do this.

# First let's make a function to sort through the sex 
def male_female_child(passenger):
    # Take the Age and Sex
    age,sex = passenger
    # Compare the age, otherwise leave the sex
    if age < 16:
        return 'child'
    else:
        return sex

# %%
titanic['Person']=titanic[['Age','Sex']].apply(male_female_child,axis=1)

# %%
titanic.head(10)
# Out:
#       Sex  PassengerId  Survived  Pclass  \
# 0    male            1         0       3
# 1  female            2         1       1
# 2  female            3         1       3
# 3  female            4         1       1
# 4    male            5         0       3
# 5    male            6         0       3
# 6    male            7         0       1
# 7    male            8         0       3
# 8  female            9         1       3
# 9  female           10         1       2
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
# ...

# %%
sns.countplot(data=titanic,x='Pclass',hue='Person')
plt.show()

# %%
titanic['Age'].hist(bins=60)
plt.show()

# %%
titanic['Age'].mean()
# Out:
# 29.69911764705882

# %% [markdown]
# #### THIS FUNCTION IS ONE OF THE MOST USE_FULL ONE REMEMBER IT WELL THIS WILL TELL ONE COLUMN AND HIS SUMMARIZED DETAILS

# %%
titanic['Person'].value_counts()
# Out:
# Person
# male      537
# female    271
# child      83
# Name: count, dtype: int64

# %%
titanic.loc[titanic['Sex'] == 'male'].loc[titanic['Age'].idxmax()]
# Out:
# Sex                                            male
# PassengerId                                     631
# Survived                                          1
# Pclass                                            1
# Name           Barkworth, Mr. Algernon Henry Wilson
# Age                                            80.0
# SibSp                                             0
# Parch                                             0
# Ticket                                        27042
# Fare                                           30.0
# Cabin                                           A23
# Embarked                                          S
# Person                                         male
# Name: 630, dtype: object

# %%
titanic[titanic['Sex'].str.contains('female')].head()
# Out:
#       Sex  PassengerId  Survived  Pclass  \
# 1  female            2         1       1
# 2  female            3         1       3
# 3  female            4         1       1
# 8  female            9         1       3
# 9  female           10         1       2
#
#                                                 Name   Age  SibSp  Parch  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0      0      2
# 9                Nasser, Mrs. Nicholas (Adele Achem)  14.0      1      0
#
#              Ticket     Fare Cabin Embarked  Person
# 1          PC 17599  71.2833   C85        C  female
# 2  STON/O2. 3101282   7.9250   NaN        S  female
# 3            113803  53.1000  C123        S  female
# 8            347742  11.1333   NaN        S  female
# ...

# %% [markdown]
# # PART 2 IN TITANIC PROJECT

# %%
# Another way to visualize the data is to use FacetGrid to plot multiple kedplots on one plot

# Set the figure equal to a facetgrid with the pandas dataframe as its data source, set the hue, and change the aspect ratio.
fig = sns.FacetGrid(titanic, hue="Sex",aspect=4)

# Next use map to plot all the possible kdeplots for the 'Age' column by the hue choice
fig.map(sns.kdeplot,'Age',fill= True)

# Set the x max limit by the oldest passenger
oldest = titanic['Age'].max()

#Since we know no one can be negative years old set the x lower limit at 0
fig.set(xlim=(0,oldest))

#Finally add a legend
fig.add_legend()
plt.show()

# %%
fig = sns.FacetGrid(titanic, hue="Person",aspect=4)
fig.map(sns.kdeplot,'Age',fill= True)
oldest = titanic['Age'].max()
fig.set(xlim=(0,oldest))
fig.add_legend()
plt.show()

# %%
fig = sns.FacetGrid(titanic, hue="Pclass",aspect=4)
fig.map(sns.kdeplot,'Age',fill= True)
oldest = titanic['Age'].max()
fig.set(xlim=(0,oldest))
fig.add_legend()
plt.show()

# %% [markdown]
# # 2.What deck were the passengers on and how does that relate to their class?

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
Deck=titanic['Cabin'].dropna(inplace=True)

# %%
titanic['Cabin'].dropna(inplace=True)

# %%
titanic.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.fillna('')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.dropna(inplace=True)

# %%
titanic.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
deck = titanic['Cabin'].dropna()

# %%
# So let's grab that letter for the deck level with a simple for loop

# Set empty list
levels = []

# Loop to grab first letter
for level in deck:
    levels.append(level[0])    

# Reset DataFrame and use factor plot
cabin_df = pd.DataFrame(levels)
cabin_df.columns = ['Cabin']
sns.countplot(x='Cabin',data=cabin_df,palette='brg')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19584\4102394368.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Cabin',data=cabin_df,palette='brg')

# %% [markdown]
# # 3.Where did the passengers come from?

# %%
titanic.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
# Now we can make a quick factorplot to check out the results, note the x_order argument, used to deal with NaN values
sns.countplot(x='Embarked',data=titanic,hue='Pclass',order=['C','Q','S'],palette='winter_d')
plt.show()

# %% [markdown]
# # 4. Who was alone and who was with family?

# %%
titanic.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
titanic['Alone']=titanic.SibSp + titanic.Parch

# %%
titanic['Alone'].head()
# Out:
# 1     1
# 3     1
# 6     0
# 10    2
# 11    0
# Name: Alone, dtype: int64

# %%
titanic['Alone'].unique()  # Show all unique values
# Out:
# array([1, 0, 2, 5, 3, 4], dtype=int64)

# %%
titanic['Alone'] = pd.to_numeric(titanic['Alone'], errors='coerce')

# %%
titanic['Alone'].dtype
# Out:
# dtype('int64')

# %%
titanic['Alone'].loc[titanic['Alone']>0] = 'With Family'
titanic.loc[titanic['Alone'] == 0, 'Alone'] = 'Alone'
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19584\3241476158.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   titanic['Alone'].loc[titanic['Alone']>0] = 'With Family'
# ...

# %%
titanic.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked        Alone
# 1       0  PC 17599  71.2833   C85        C  With Family
# 3       0    113803  53.1000  C123        S  With Family
# 6       0     17463  51.8625   E46        S        Alone
# 10      1   PP 9549  16.7000    G6        S  With Family
# ...

# %%
sns.countplot(x='Alone',data=titanic,palette='cool')
plt.show()

# %% [markdown]
# # 5.What factors helped someone survive the sinking?

# %%
titanic.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked        Alone
# 1       0  PC 17599  71.2833   C85        C  With Family
# 3       0    113803  53.1000  C123        S  With Family
# 6       0     17463  51.8625   E46        S        Alone
# 10      1   PP 9549  16.7000    G6        S  With Family
# ...

# %%
# Let's start by creating a new column for legibility purposes through mapping (Lec 36)
titanic["Survivor"] = titanic.Survived.map({0: "no", 1: "yes"})

# %%
titanic.head(4)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
#
#     Parch    Ticket     Fare Cabin Embarked        Alone Survivor
# 1       0  PC 17599  71.2833   C85        C  With Family      yes
# 3       0    113803  53.1000  C123        S  With Family      yes
# 6       0     17463  51.8625   E46        S        Alone       no
# 10      1   PP 9549  16.7000    G6        S  With Family      yes

# %%
 sns.countplot(x='Survivor',data=titanic,palette=["#4CAF50", "#FF9800", "#2196F3"])
plt.show()

# %%
sns.countplot(x='Survivor',data=titanic,hue='Pclass',palette='coolwarm')
plt.show()

# %%
# Let's use a factor plot again, but now considering class
sns.countplot(x='Pclass', hue='Survived',data=titanic)
plt.show()

# %%
titanic.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked        Alone Survivor
# 1       0  PC 17599  71.2833   C85        C  With Family      yes
# 3       0    113803  53.1000  C123        S  With Family      yes
# 6       0     17463  51.8625   E46        S        Alone       no
# ...

# %%
# Let's use a linear plot on age versus survival using hue for class seperation
generations=[10,20,40,60,80]

# %%
sns.lmplot(x='Age',y='Survived',data=titanic,x_bins=generations)
plt.show()

# %%
sns.lmplot(x='Age',y='Survived',hue='Pclass',data=titanic,palette='dark',x_bins=generations)
plt.show()

# %%
sns.lmplot(x='Survived',y='Age',data=titanic,palette='winter',x_bins=generations)
plt.show()

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic['Deck'] = titanic['Cabin'].str[0]  # Get the first letter of Cabin
titanic['Deck'] = titanic['Deck'].fillna('Unknown')  # Fill missing values

# %%
titanic.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked        Alone Survivor Deck
# 1       0  PC 17599  71.2833   C85        C  With Family      yes    C
# 3       0    113803  53.1000  C123        S  With Family      yes    C
# 6       0     17463  51.8625   E46        S        Alone       no    E
# ...

# %%
deck_survival = titanic.groupby('Deck')['Survived'].mean().sort_values(ascending=False)

# %%
titanic.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked        Alone Survivor Deck
# 1       0  PC 17599  71.2833   C85        C  With Family      yes    C
# 3       0    113803  53.1000  C123        S  With Family      yes    C
# 6       0     17463  51.8625   E46        S        Alone       no    E
# ...

# %%
sns.barplot(x=deck_survival.index, y=deck_survival.values, palette='coolwarm')
plt.title('Survival Rate by Deck')
plt.show()

# %%
# Create a FamilySize column
titanic['FamilySize'] = titanic['SibSp'] + titanic['Parch']

# Compare survival rates by family size
family_survival = titanic.groupby('FamilySize')['Survived'].mean()

# Plot survival rates by family size
sns.lineplot(x=family_survival.index, y=family_survival.values, marker='o')
plt.title('Survival Rate by Family Size')
plt.show()

# %%
titanic.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked        Alone Survivor Deck  \
# 1       0  PC 17599  71.2833   C85        C  With Family      yes    C
# 3       0    113803  53.1000  C123        S  With Family      yes    C
# 6       0     17463  51.8625   E46        S        Alone       no    E
# ...

# %%
from IPython.display import Image
Image(url='http://i.imgur.com/DGNjT.gif')
# Out:
# <img src="http://i.imgur.com/DGNjT.gif"/>
